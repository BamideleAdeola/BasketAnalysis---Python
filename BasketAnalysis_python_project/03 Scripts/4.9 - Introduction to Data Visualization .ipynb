# %% [markdown]
# ## 4.9 - Introduction to Data Visualization

# %% [markdown]
# Table of contents
# #### Creating Bar Charts
# #### Creating Histograms and Scatterplots
# #### Creating Line Chart
# #### Sampling Data

# %%
# import libraries
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt
import scipy

# %% [markdown]
# Visualization libraries
# - seaborn
# - matplotlib
# - scipy

# %%
folderpath = r'C:\Users\Bamidele\Desktop\Training_content\Data Analytics Training - Techbams Solutions\Python\BasketAnalysis_python_project'

# %%
ords_prods_merge = pd.read_pickle( os.path.join(folderpath, '02 Data', 'Cleaned Data', 'ords_prods_mergeGrouping.pkl'))

# %%
ords_prods_merge.head()

# %% [markdown]
# #### Creating Bar Charts

# %%
ords_prods_merge['orders_day_of_week'].value_counts()
# Out:
# orders_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
ords_prods_merge['orders_day_of_week'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='orders_day_of_week'>

# %%
ords_prods_merge['orders_day_of_week'].value_counts().sort_index()
# Out:
# orders_day_of_week
# 0    6204182
# 1    5660230
# 2    4213830
# 3    3840534
# 4    3783802
# 5    4205791
# 6    4496490
# Name: count, dtype: int64

# %%
# sort index first 


ords_prods_merge['orders_day_of_week'].value_counts().sort_index().plot.bar()
# Out:
# <Axes: xlabel='orders_day_of_week'>

# %%
# - categorical 
# - numerica or continuous

# %%
# sort index first 


# ords_prods_merge['orders_day_of_week'].value_counts().sort_index().plot.()
# Out:
# <Axes: ylabel='count'>

# %%
chart_colors = []

# %%
# Adding color

ords_prods_merge['orders_day_of_week'].value_counts().sort_index().plot.bar(color = ['green', 'yellow', 'purple', 'pink', 'red', 'blue', 'orange' ]  )
# Out:
# <Axes: xlabel='orders_day_of_week'>

# %%
bar = ords_prods_merge['orders_day_of_week'].value_counts().sort_index().plot.bar(color = ['green', 'yellow', 'purple', 'pink', 'red', 'blue', 'orange' ]  )

# %%
bar.figure

# %%
# save my image to visulaization folder
bar.figure.savefig(os.path.join(folderpath, '04 Analysis', 'Visualization', 'bar_orders_dow.png') )

# %% [markdown]
# #### Creating Histograms and Scatterplots

# %%
ords_prods_merge['prices'].plot.hist(bins = 25)

# %%
ords_prods_merge['prices'].describe()
# Out:
# count    3.240486e+07
# mean     1.198023e+01
# std      4.956554e+02
# min      1.000000e+00
# 25%      4.200000e+00
# 50%      7.400000e+00
# 75%      1.130000e+01
# max      9.999900e+04
# Name: prices, dtype: float64

# %%
ords_prods_merge['prices'].mean()
# Out:
# 11.980225638383445

# %%
ords_prods_merge['prices'].median()
# Out:
# 7.4

# %%
ords_prods_merge['prices'].max()
# Out:
# 99999.0

# %%
# sns.scatterplot(x = 'prices', y = 'prices', data = ords_prods_merge)

# %%
ords_prods_merge.loc[ ords_prods_merge['prices'] > 100 ]

# %%
ords_prods_merge.loc[ ords_prods_merge['prices'] > 100 ] = np.nan

# %%
ords_prods_merge['prices'].max()
# Out:
# 25.0

# %%
hist = ords_prods_merge['prices'].plot.hist(bins = 25)

# %%
hist_2 = ords_prods_merge['prices'].plot.hist(bins = 70)

# %%
# save my image to visulaization folder
hist.figure.savefig(os.path.join(folderpath, '04 Analysis', 'Visualization', 'hist_prices.png') )

# %%
# save my image to visulaization folder
hist_2.figure.savefig(os.path.join(folderpath, '04 Analysis', 'Visualization', 'hist_prices70bins.png') )

# %% [markdown]
# #### Creating Line Chart

# %%
df = ords_prods_merge[:2000000]

# %% [markdown]
# #### Sampling Data

# %%
np.random.seed(4)

# %%
dev = np.random.rand(len(ords_prods_merge)) <= 0.7

# %%
dev
# Out:
# array([False,  True, False, ...,  True,  True,  True])

# %%
np.random.rand(6)
# Out:
# array([0.93546686, 0.06557465, 0.85698584, 0.24456371, 0.22683171,
#        0.17068366])

# %%
len(ords_prods_merge)
# Out:
# 32404859

# %%
big = ords_prods_merge[dev]
small = ords_prods_merge[~dev]

# %%
len(ords_prods_merge)
# Out:
# 32404859

# %%
len(big)
# Out:
# 22683761

# %%
len(small)
# Out:
# 9721098

# %%
len(small) + len(big)
# Out:
# 32404859

# %%
df_2 = small[['orders_day_of_week', 'prices']]

# %%
df_2.head()
# Out:
#     orders_day_of_week  prices
# 0                  2.0     9.0
# 2                  2.0     4.4
# 3                  2.0     4.7
# 6                  3.0     3.0
# 10                 3.0     4.0

# %%
line = sns.lineplot(data = df_2, x = 'orders_day_of_week', y = 'prices')

# %%
print(df_2.shape)
print(df_4.shape)
# Out:
# (9721098, 2)
# (32404859, 2)

# %%
df_4 = ords_prods_merge[['orders_day_of_week', 'prices']]

# %%
line_2 = sns.lineplot(data = df_4, x = 'orders_day_of_week', y = 'prices')

# %%
# save my image to visulaization folder
line.figure.savefig(os.path.join(folderpath, '04 Analysis', 'Visualization', 'line_orders_day_of_week_pricesSampledata.png') )
line_2.figure.savefig(os.path.join(folderpath, '04 Analysis', 'Visualization', 'line_orders_day_of_week_pricesAllData.png') )
