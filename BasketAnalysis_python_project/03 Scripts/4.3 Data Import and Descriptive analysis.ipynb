# %% [markdown]
# # **Introduction to Pandas**
# **Learning goals**:
# - Dataframe in Pandas
# - Descriptive analysis
# - Data cleaning
#
# **Functions**
# - Importing and exporting data
# - Merge data,
# - renaming and drop column

# %% [markdown]
# ## Python Data Structures: Dataframes

# %% [markdown]
# ### Importing a Data Set in Jupyter

# %% [markdown]
# # 01. Importing Libraries

# %%
# import libraries
import numpy as np 
import pandas as pd
import os

# %%
df = pd.read_csv(r'C:\Users\Bamidele\Desktop\Training_content\Data Analytics Training - Techbams Solutions\Python\BasketAnalysis_python_project\02 Data\Raw Data\orders.csv', index_col = False)

# %%
df.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %% [markdown]
# ## Python Shortcut for importing Data Files

# %%
# os.path.join()

# %%
path = r'C:\Users\Bamidele\Desktop\Training_content\Data Analytics Training - Techbams Solutions\Python\BasketAnalysis_python_project'

# %%
path
# Out:
# 'C:\\Users\\Bamidele\\Desktop\\Training_content\\Data Analytics Training - Techbams Solutions\\Python\\BasketAnalysis_python_project'

# %%
df = pd.read_csv(os.path.join(path , '02 Data', 'Raw Data', 'orders.csv'  ), index_col = False )

# %%
# display the first five rows of data
df.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df.head(20)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 1    2398795        1    prior             2          3                  7
# 2     473747        1    prior             3          3                 12
# 3    2254736        1    prior             4          4                  7
# 4     431534        1    prior             5          4                 15
# 5    3367565        1    prior             6          2                  7
# 6     550135        1    prior             7          1                  9
# 7    3108588        1    prior             8          1                 14
# 8    2295261        1    prior             9          1                 16
# 9    2550362        1    prior            10          4                  8
# 10   1187899        1    train            11          4                  8
# ...

# %%
# last five rows of data
df.tail(35)
# Out:
#          order_id  user_id eval_set  order_number  order_dow  \
# 3421048    726186   206208    prior            30          0
# 3421049   2523609   206208    prior            31          4
# 3421050    756221   206208    prior            32          6
# 3421051   2254244   206208    prior            33          6
# 3421052   2017995   206208    prior            34          6
# 3421053   2789700   206208    prior            35          3
# 3421054    844592   206208    prior            36          6
# 3421055   1541132   206208    prior            37          2
# 3421056   2808240   206208    prior            38          0
# 3421057   3027766   206208    prior            39          2
# 3421058   3356245   206208    prior            40          5
# 3421059    442304   206208    prior            41          2
# 3421060   2675140   206208    prior            42          1
# 3421061    167903   206208    prior            43          4
# ...

# %%
# shape function - returns dimension of a data frame ( rows and columns)

df.shape
# Out:
# (3421083, 7)

# %% [markdown]
# My dataset has a total of
# - **3m** plus rows of data and
# - **7** columns

# %%
# info function - 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3421083 entries, 0 to 3421082
# Data columns (total 7 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   user_id                 int64
#  2   eval_set                object
#  3   order_number            int64
#  4   order_dow               int64
#  5   order_hour_of_day       int64
#  6   days_since_prior_order  float64
# dtypes: float64(1), int64(5), object(1)
# memory usage: 182.7+ MB

# %%
# dtypes gives the type of the columns

df.dtypes
# Out:
# order_id                    int64
# user_id                     int64
# eval_set                   object
# order_number                int64
# order_dow                   int64
# order_hour_of_day           int64
# days_since_prior_order    float64
# dtype: object

# %%
# display columns alone
df.columns
# Out:
# Index(['order_id', 'user_id', 'eval_set', 'order_number', 'order_dow',
#        'order_hour_of_day', 'days_since_prior_order'],
#       dtype='object')

# %%
# describe function - gives summary of the numeric dataset
df.describe()
# Out:
#            order_id       user_id  order_number     order_dow  \
# count  3.421083e+06  3.421083e+06  3.421083e+06  3.421083e+06
# mean   1.710542e+06  1.029782e+05  1.715486e+01  2.776219e+00
# std    9.875817e+05  5.953372e+04  1.773316e+01  2.046829e+00
# min    1.000000e+00  1.000000e+00  1.000000e+00  0.000000e+00
# 25%    8.552715e+05  5.139400e+04  5.000000e+00  1.000000e+00
# 50%    1.710542e+06  1.026890e+05  1.100000e+01  3.000000e+00
# 75%    2.565812e+06  1.543850e+05  2.300000e+01  5.000000e+00
# max    3.421083e+06  2.062090e+05  1.000000e+02  6.000000e+00
#
#        order_hour_of_day  days_since_prior_order
# count       3.421083e+06            3.214874e+06
# mean        1.345202e+01            1.111484e+01
# std         4.226088e+00            9.206737e+00
# min         0.000000e+00            0.000000e+00
# 25%         1.000000e+01            4.000000e+00
# 50%         1.300000e+01            7.000000e+00
# 75%         1.600000e+01            1.500000e+01
# ...

# %% [markdown]
# # Python Data Structures: Lists

# %%
df3 = pd.read_csv(os.path.join(path, '02 Data', 'Raw Data', 'Orders.csv') , nrows = 1000  )

# %%
df3.shape
# Out:
# (1000, 7)

# %%
df3.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2398795        1    prior             2          3                  7
# 2    473747        1    prior             3          3                 12
# 3   2254736        1    prior             4          4                  7
# 4    431534        1    prior             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
# df3['eval_set']

# %%
vars_list = ['order_id', 'user_id', 'order_number', 'order_dow', 'order_hour_of_day', 'days_since_prior_order']

# %%
vars_list
# Out:
# ['order_id',
#  'user_id',
#  'order_number',
#  'order_dow',
#  'order_hour_of_day',
#  'days_since_prior_order']

# %%
vars_list2 = ['order_number', 'order_dow', 'order_hour_of_day', 'days_since_prior_order']

# %%
vars_list2
# Out:
# ['order_number', 'order_dow', 'order_hour_of_day', 'days_since_prior_order']

# %%
df4 = pd.read_csv(os.path.join(path, '02 Data', 'Raw Data', 'Orders.csv') , nrows = 1000, usecols = vars_list )

# %%
df4.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df = pd.read_csv(os.path.join(path, '02 Data', 'Raw Data', 'Orders.csv') , usecols = vars_list )

# %%
df.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1             1          2                  8
# 1   2398795        1             2          3                  7
# 2    473747        1             3          3                 12
# 3   2254736        1             4          4                  7
# 4    431534        1             5          4                 15
#
#    days_since_prior_order
# 0                     NaN
# 1                    15.0
# 2                    21.0
# 3                    29.0
# 4                    28.0

# %%
df.shape
# Out:
# (3421083, 6)

# %%
df4 = pd.read_csv(os.path.join(path, '02 Data', 'Raw Data', 'Orders.csv') , nrows = 1000, usecols = vars_list2 )

# %%
df4.head()
# Out:
#    order_number  order_dow  order_hour_of_day  days_since_prior_order
# 0             1          2                  8                     NaN
# 1             2          3                  7                    15.0
# 2             3          3                 12                    21.0
# 3             4          4                  7                    29.0
# 4             5          4                 15                    28.0

# %%
a = ['bamidele', 3, 5, 'Kola']

# %%
a
# Out:
# ['bamidele', 3, 5, 'Kola']
