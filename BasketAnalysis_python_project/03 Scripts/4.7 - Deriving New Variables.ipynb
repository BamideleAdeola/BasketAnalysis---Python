# %% [markdown]
# ## 4.7 - Deriving New Variables

# %%
# debt
# income

# %% [markdown]
# ##### Table of Content
# #### If statement
# #### If Statement with User Define Function

# %%
df.describe

# %% [markdown]
# #### If Statement

# %% [markdown]
# #### If Statement with User Define Function

# %%
# Define function
def adding_numbers(x, y):
    sum = x + y
    return sum

# %%
adding_numbers(11, 20)
# Out:
# 31

# %%
# Define function
def adding_mynum(x, y, z):
    thenumbers = x + y - z
    return thenumbers

# %%
adding_mynum(20, 10, 5)
# Out:
# 25

# %%
ords_prods_merge

# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
folderpath = r'C:\Users\Bamidele\Desktop\Training_content\Data Analytics Training - Techbams Solutions\Python\BasketAnalysis_python_project'

# %%
ords_prods_merge = pd.read_pickle( os.path.join(folderpath, '02 Data', 'Cleaned Data', 'orders_products_combined.pkl'))

# %% [markdown]
# - If the item’s price is lower than or equal to 5, it will be labeled a low-range product.
# - If the item’s price is above 5 but lower than or equal to 15, it will be labeled a mid-range product.
# - If the item’s price is above 15, it will be labeled a high-range product.

# %%
products =  pd.read_csv( os.path.join(folderpath, '02 Data', 'Cleaned Data', 'products_checked.csv'), index_col= False)

# %%
products.drop(columns = ['Unnamed: 0'], inplace= True)

# %%
products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %%
ords_prods_merge.drop(columns = ['_merge'], inplace= True)

# %%
ords_prods_merge_new = ords_prods_merge.merge( products,  on = 'product_id',   indicator = True)

# %%
ords_prods_merge_new.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# ...

# %%
ords_prods_merge_new['_merge']. value_counts()
# Out:
# _merge
# both          32404859
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
# def price_tag()

# %%
ords_prods_merge.shape

# %%
# create a subset of the dataframe
df = ords_prods_merge[:1000000]

# %%
df.shape

# %%
df.head()

# %%
# ords_prods_merge['prices']

# %%
# export to pickle file
ords_prods_merge_new.to_pickle(os.path.join( folderpath, '02 Data', 'Cleaned Data', 'ords_prods_merge.pkl') )

# %%
ords_prods_merge = pd.read_pickle( os.path.join(folderpath, '02 Data', 'Cleaned Data', 'ords_prods_merge.pkl'))

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# ...

# %% [markdown]
# - If the item’s price is lower than or equal to 5, it will be labeled a low-range product.
# - If the item’s price is above 5 but lower than or equal to 15, it will be labeled a mid-range product.
# - If the item’s price is above 15, it will be labeled a high-range product.

# %%
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: 
      return 'Not enough data'

# %%
# df['price_range'] = df.apply(price_label,  axis = 1)

# %%
# df.head()

# %%
df['price_range'].value_counts()
# Out:
# price_range
# Mid-range product    673183
# Low-range product    314392
# High range            12425
# Name: count, dtype: int64

# %%
df['prices'].max()
# Out:
# 99999.0

# %% [markdown]
# #### If statement with loc() function

# %%
df.loc[           ]

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5) , 'price_range_loc'] = 'Mid range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low range product'

# %%
df.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# ...

# %%
df['price_range_loc'].value_counts()
# Out:
# price_range_loc
# Low range product     314392
# High range product     12425
# Name: count, dtype: int64

# %%
ords_prods_merge.shape
# Out:
# (32404859, 14)

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High range product'

# %%
ords_prods_merge.loc[(ords_prods_merge['prices'] <= 15) & (ords_prods_merge['prices'] > 5) , 'price_range_loc'] = 'Mid range product'

# %%
ords_prods_merge.loc[ords_prods_merge['prices'] <= 5, 'price_range_loc'] = 'Low range product'

# %%
ords_prods_merge['price_range_loc'].value_counts()
# Out:
# price_range_loc
# Mid range product     21860860
# Low range product     10126321
# High range product      417678
# Name: count, dtype: int64

# %%
ords_prods_merge['prices'].max()
# Out:
# 99999.0

# %% [markdown]
# #### If Statement with For-Loop

# %%
print("My age is 50")
# Out:
# My age is 50

# %%
print("My age is 51")
# Out:
# My age is 51

# %%
print("My age is 52")
# Out:
# My age is 52

# %%
print("My age is 53")
# Out:
# My age is 53

# %%
for x in range(50, 66):
    print("My age is %d" % (x)  )
# Out:
# My age is 50
# My age is 51
# My age is 52
# My age is 53
# My age is 54
# My age is 55
# My age is 56
# My age is 57
# My age is 58
# My age is 59
# My age is 60
# My age is 61
# My age is 62
# My age is 63
# My age is 64
# My age is 65

# %%
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0
#
#                               product_name  aisle_id  department_id  prices  \
# ...

# %%
ords_prods_merge['orders_day_of_week'].value_counts(dropna = False)
# Out:
# orders_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
Busiest day
least busy 
regularly busy

# %%
result = []

# %%
result
# Out:
# []

# %%
for value in ords_prods_merge["orders_day_of_week"]:
    if value == 0:
        result.append("Busiest day")
    elif value == 4:
        result.append("Least Busy")
    else:
        result.append("Regularly Busy")

# %%
result
# Out:
# ['Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Least Busy',
#  'Least Busy',
#  'Least Busy',
#  'Least Busy',
#  'Least Busy',
#  'Least Busy',
#  'Least Busy',
#  'Least Busy',
#  'Least Busy',
#  'Least Busy',
#  'Least Busy',
#  'Least Busy',
#  'Least Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
#  'Regularly Busy',
# ...

# %%
ords_prods_merge['busiest day'] = result

# %%
ords_prods_merge['busiest day'].value_counts(dropna = False)
# Out:
# busiest day
# Regularly Busy    22416875
# Busiest day        6204182
# Least Busy         3783802
# Name: count, dtype: int64

# %%
ords_prods_merge.to_pickle(os.path.join( folderpath, '02 Data', 'Cleaned Data', 'ords_prods_mergeNew.pkl') )
